# %%
import json
import requests

# %%
url = 'https://api.jsonbin.io/b/5cd08ec9c07f283511e13f74'
headers = {'Content-Type': 'application/json', 'secret-key': '$2a$10$hZigRrBAVGWt/XKwITBi8.UHTraYPkLR5WNmlMeVVv97qr1NNGvJe', 'versioning': 'false'}
data = json.loads(open("futurePred.json").read())
temp = json.dumps(data)
data = json.loads(temp)
print (type(data))
# Out:
# <class 'list'>

# %%
req = requests.put(url, json=data, headers=headers)
print(req.text)
# Out:
# {"success":true,"data":[{"date":"5/10/2019","lat":"12.66644","lon":"100.90073","state":"Chon Buri","country":"TH","place":"Sattahip"},{"date":"5/10/2019","lat":"12.66644","lon":"100.90073","state":"Chon Buri","country":"TH","place":"Sattahip"},{"date":"5/10/2019","lat":"13.54753","lon":"100.27362","state":"Samut Sakhon","country":"TH","place":"Samut Sakhon"},{"date":"5/12/2019","lat":"13.66744","lon":"100.64206","state":"Bangkok","country":"TH","place":"Bang Na"},{"date":"5/12/2019","lat":"14.02114","lon":"100.73433","state":"Pathum Thani","country":"TH","place":"Thanyaburi"},{"date":"5/13/2019","lat":"13.311","lon":"101.11214","state":"Chon Buri","country":"TH","place":"Ban Bueng"},{"date":"5/13/2019","lat":"14.64681","lon":"100.57617","state":"Phra Nakhon Si Ayutthaya","country":"TH","place":"Ban Phraek"},{"date":"5/13/2019","lat":"13.802","lon":"100.32111","state":"Nakhon Pathom","country":"TH","place":"Salaya"},{"date":"5/13/2019","lat":"13.70528","lon":"100.34923","state":"Bangk
# ...
